# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sns
# %matplotlib inline
#Basic Possession Formula=
#0.96*[(Field Goal Attempts)+(Turnovers)+0.44*(Free Throw Attempts)-(Offensive Rebounds)]
#source: https://www.nbastuffer.com/analytics101/possession/

# %%
reg_season_compact = pd.read_csv('RegularSeasonCompactResults.csv')
reg_season_detail = pd.read_csv('RegularSeasonDetailedResults.csv')
tourn_compact = pd.read_csv('TourneyCompactResults.csv')
tourn_detail = pd.read_csv('TourneyDetailedResults.csv')
tourn_seeds = pd.read_csv('TourneySeeds.csv')
seasons = pd.read_csv('Seasons.csv')
teams = pd.read_csv('Teams.csv')

# %%
#dataframe of first round results
first_round = tourn_compact[(tourn_compact['Daynum']==137) | (tourn_compact['Daynum']==136)]

# %%
reg_season_compact.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0

# %% [markdown]
# # Create Wins and Loss Tables

# %%
#calculate total loses per season
loses_season=reg_season_detail[['Season','Lteam']]
loses_season=loses_season.groupby(['Season','Lteam']).size()
loses_season = loses_season.to_frame(name = 'size').reset_index()
loses_season.columns=['Season','Lteam','Total_Loses']
loses_season
#Calculate total wins per season
wins_season=reg_season_detail[['Season','Wteam']]
wins_season=wins_season.groupby(['Season','Wteam']).size()
wins_season = wins_season.to_frame(name = 'size').reset_index()
wins_season.columns=['Season','Wteam','Total_Wins']
wins_season
#combine tables for record per season
win_loss_record = pd.merge(loses_season, wins_season,  how='outer', left_on=['Season','Lteam'], right_on = ['Season','Wteam'])
win_loss_record = pd.merge(win_loss_record, teams, how='inner', left_on='Lteam', right_on='Team_Id')
win_loss_record= pd.merge(win_loss_record,tourn_seeds,how='inner', left_on=['Season','Lteam'], right_on=['Season','Team'])
win_loss_record=win_loss_record[['Season','Lteam','Team_Name','Total_Wins', 'Total_Loses','Seed']]
win_loss_record['Total_Games']=win_loss_record['Total_Wins']+win_loss_record['Total_Loses']

# %% [markdown]
# # Winning Team Aggregate Stats

# %%
#Winning Team Aggregate Stats
wteam_agg=reg_season_detail.groupby(['Season','Wteam']).agg({'Wscore':'sum', 'Wfgm':'sum', 'Wfga':'sum'
                                                            ,'Wfgm3':'sum','Wfga3':'sum','Wftm':'sum',
                                                            'Wftm':'sum','Wfta':'sum','Wor':'sum','Wdr':'sum',
                                                             'Wast':'sum','Wstl':'sum',
                                                            'Wblk':'sum','Wto':'sum',
                                                            'Wpf':'sum'}).reset_index()

# %% [markdown]
# # Losing Team Aggregate Stats

# %%
#Losing Team Aggregate Stats
lteam_agg=reg_season_detail.groupby(['Season','Lteam']).agg({'Lscore':'sum', 'Lfgm':'sum', 'Lfga':'sum'
                                                            ,'Lfgm3':'sum','Lfga3':'sum','Lftm':'sum',
                                                            'Lftm':'sum','Lfta':'sum','Lor':'sum','Ldr':'sum',
                                                             'Last':'sum','Lstl':'sum',
                                                            'Lblk':'sum','Lto':'sum',
                                                            'Lpf':'sum'}).reset_index()

# %%
Opp Stats - Losing Teams

# %%
#Opp Stats - Losing Teams
Opp_stat_losing_teams=reg_season_detail.groupby(['Season','Lteam']).agg({'Wscore':'sum', 'Wfgm':'sum', 'Wfga':'sum'
                                                            ,'Wfgm3':'sum','Wfga3':'sum','Wftm':'sum',
                                                            'Wftm':'sum','Wfta':'sum','Wor':'sum','Wdr':'sum',
                                                             'Wast':'sum','Wstl':'sum',
                                                            'Wblk':'sum','Wto':'sum',
                                                            'Wpf':'sum'}).reset_index()
Opp_stat_losing_teams.head()
# Out:
#    Season  Lteam  Wscore  Wfgm  Wfga  Wfgm3  Wfga3  Wftm  Wfta  Wor  Wdr  \
# 0    2003   1102     958   312   628     76    178   258   365  142  348
# 1    2003   1103    1091   392   759     97    231   210   296  151  334
# 2    2003   1104     774   275   576     74    201   150   212  114  245
# 3    2003   1105    1528   541  1130    132    334   314   472  251  521
# 4    2003   1106    1032   364   793     82    244   222   313  168  371
#
#    Wast  Wstl  Wblk  Wto  Wpf
# 0   164    81    33  193  271
# 1   240    89    45  206  280
# 2   143    67    46  131  195
# 3   324   194    81  335  356
# 4   210   133    57  215  216

# %%
#Opp Stats - Winning Teams
Opp_stat_winning_teams=reg_season_detail.groupby(['Season','Wteam']).agg({'Lscore':'sum', 'Lfgm':'sum', 'Lfga':'sum'
                                                            ,'Lfgm3':'sum','Lfga3':'sum','Lftm':'sum',
                                                            'Lftm':'sum','Lfta':'sum','Lor':'sum','Ldr':'sum',
                                                             'Last':'sum','Lstl':'sum',
                                                            'Lblk':'sum','Lto':'sum',
                                                            'Lpf':'sum'}).reset_index()
Opp_stat_winning_teams.head()
# Out:
#    Season  Wteam  Lscore  Lfgm  Lfga  Lfgm3  Lfga3  Lftm  Lfta  Lor  Ldr  \
# 0    2003   1102     638   228   560     57    170   125   174  127  216
# 1    2003   1103    1019   358   780     83    265   220   302  174  261
# 2    2003   1104    1046   376   978    104    335   190   268  191  389
# 3    2003   1105     465   161   403     31    122   112   165   92  165
# 4    2003   1106     753   244   702     52    182   213   302  149  255
#
#    Last  Lstl  Lblk  Lto  Lpf
# 0    92    71    11  170  243
# 1   178    84    32  208  326
# 2   184    88    43  257  344
# 3    87    50    28  154  140
# 4   120   113    32  207  236

# %%
#creating table of opponent stats
opp_stat1=pd.merge(Opp_stat_winning_teams, win_loss_record,  how='inner', left_on=['Season','Wteam'], right_on = ['Season','Lteam'])
opp_stat_final=pd.merge(opp_stat1, Opp_stat_losing_teams,  how='inner', left_on=['Season','Wteam'], right_on = ['Season','Lteam'])
opp_stat_final.columns
# Out:
# Index(['Season', 'Wteam', 'Lscore', 'Lfgm', 'Lfga', 'Lfgm3', 'Lfga3', 'Lftm',
#        'Lfta', 'Lor', 'Ldr', 'Last', 'Lstl', 'Lblk', 'Lto', 'Lpf', 'Lteam_x',
#        'Team_Name', 'Total_Wins', 'Total_Loses', 'Seed', 'Total_Games',
#        'Lteam_y', 'Wscore', 'Wfgm', 'Wfga', 'Wfgm3', 'Wfga3', 'Wftm', 'Wfta',
#        'Wor', 'Wdr', 'Wast', 'Wstl', 'Wblk', 'Wto', 'Wpf'],
#       dtype='object')

# %% [markdown]
# # Opp Stats Aggregate

# %%
opp_stat_final

#create new columns
# total pts and pts per game allowed
opp_stat_final['Tpts_allowed']=opp_stat_final['Wscore']+opp_stat_final['Lscore']
opp_stat_final['Tpts_allowed_per_game']=opp_stat_final['Tpts_allowed']/opp_stat_final['Total_Games']

#Field goal attempted, made, and percentage allowed
opp_stat_final['Tfga_allowed'] = opp_stat_final['Wfga']+opp_stat_final['Lfga']
opp_stat_final['Tfgm_allowed'] = opp_stat_final['Wfgm']+opp_stat_final['Lfgm']
opp_stat_final['Tfg_perct_allowed']=opp_stat_final['Tfgm_allowed']/opp_stat_final['Tfga_allowed']
opp_stat_final['Tfga_allowed_per_game']=opp_stat_final['Tfga_allowed']/opp_stat_final['Total_Games']

#3pts attempted, made, and percentage allowed
opp_stat_final['Tfga3_allowed'] = opp_stat_final['Wfga3']+opp_stat_final['Lfga3']
opp_stat_final['Tfgm3_allowed'] = opp_stat_final['Wfgm3']+opp_stat_final['Lfgm3']
opp_stat_final['Tfg3_perct_allowed']=opp_stat_final['Tfgm3_allowed']/opp_stat_final['Tfga3_allowed']
opp_stat_final['T3att_allowed_per_game']=opp_stat_final['Tfga3_allowed']/opp_stat_final['Total_Games']


#Free throws attempts allowed
opp_stat_final['Tfta_allowed'] = opp_stat_final['Wfta']+opp_stat_final['Lfta']
opp_stat_final['Tfta_allowed_per_game'] = opp_stat_final['Tfta_allowed'] /opp_stat_final['Total_Games']

#Total off rebounds and off rebounds allowed per game
opp_stat_final['Tor_allowed'] = opp_stat_final['Wor']+opp_stat_final['Lor']
opp_stat_final['Tor_allowed_per_game']=opp_stat_final['Tor_allowed']/opp_stat_final['Total_Games']

#Total rebounds and rebounds per game allowed
opp_stat_final['Treb_allowed']=opp_stat_final['Wdr']+opp_stat_final['Ldr']+opp_stat_final['Wor']+opp_stat_final['Lor']
opp_stat_final['Treb_allowed_per_game']=opp_stat_final['Treb_allowed']/opp_stat_final['Total_Games']


#total fouls and fouls per game drawed
opp_stat_final['Tpf_drawed'] = opp_stat_final['Wpf']+opp_stat_final['Lpf']
opp_stat_final['Tpf_drawed_per_game']=opp_stat_final['Tpf_drawed']/opp_stat_final['Total_Games']

#Total turnovers and turnover (takaways) per game
opp_stat_final['Tto_gained'] = opp_stat_final['Wto']+opp_stat_final['Lto']
opp_stat_final['Tto_gained_per_game'] = opp_stat_final['Tto_gained']/opp_stat_final['Total_Games']



opp_stat_final.head()
# Out:
#    Season  Wteam  Lscore  Lfgm  Lfga  Lfgm3  Lfga3  Lftm  Lfta  Lor  \
# 0    2003   1104    1046   376   978    104    335   190   268  191
# 1    2003   1112    1723   653  1621    158    510   259   424  325
# 2    2003   1113    1140   411  1005     86    282   232   345  202
# 3    2003   1120    1135   415  1104    117    407   188   296  249
# 4    2003   1122    1292   468  1138    123    361   233   347  234
#
#           ...           Tfta_allowed  Tfta_allowed_per_game  Tor_allowed  \
# 0         ...                    480              17.142857          305
# 1         ...                    496              17.714286          367
# 2         ...                    595              20.517241          319
# 3         ...                    496              16.533333          367
# 4         ...                    504              18.666667          315
#
#    Tor_allowed_per_game  Treb_allowed  Treb_allowed_per_game  Tpf_drawed  \
# 0             10.892857           939              33.535714         539
# 1             13.107143          1019              36.392857         618
# 2             11.000000           915              31.551724         663
# 3             12.233333           985              32.833333         574
# 4             11.666667           923              34.185185         547
#
#   Tpf_drawed_per_game  Tto_gained  Tto_gained_per_game
# 0           19.250000         388            13.857143
# 1           22.071429         472            16.857143
# 2           22.862069         450            15.517241
# 3           19.133333         474            15.800000
# 4           20.259259         378            14.000000
#
# [5 rows x 57 columns]

# %%
#Total Posessions allowed
opp_stat_final['Tpos_allowed']=.96*[(opp_stat_final['Tfga_allowed'])+(opp_stat_final['Tto_gained'])+.44*(opp_stat_final['Tfta_allowed'])-(opp_stat_final['Tor_allowed'])]

#Pos allowed per game
opp_stat_final['Tpos_allowed_per_game']=opp_stat_final['Tpos_allowed']/opp_stat_final['Total_Games']

#Pts allowed per pos
opp_stat_final['Pts_allowed_per_pos']=opp_stat_final['Tpts_allowed']/opp_stat_final['Tpos_allowed']

#Pts per 100 pos - ORtg
opp_stat_final['Tpos_per_100']=opp_stat_final['Pts_allowed_per_pos']*100
#source: https://www.nbastuffer.com/analytics101/possession/
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8720b52cf10c> in <module>()
#       1 #Total Posessions allowed
# ----> 2 opp_stat_final['Tpos_allowed']=.96*[(opp_stat_final['Tfga_allowed'])+(opp_stat_final['Tto_gained'])+.44*(opp_stat_final['Tfta_allowed'])-(opp_stat_final['Tor_allowed'])]
#       3
#       4 #Pos allowed per game
#       5 opp_stat_final['Tpos_allowed_per_game']=opp_stat_final['Tpos_allowed']/opp_stat_final['Total_Games']
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
wteam_agg.head()
# Out:
#    Season  Wteam  Wscore  Wfgm  Wfga  Wfgm3  Wfga3  Wftm  Wfta  Wor  Wdr  \
# 0    2003   1102     825   271   480    120    259   163   249   46  232
# 1    2003   1103    1141   390   720     71    187   290   402  122  279
# 2    2003   1104    1270   439   992    120    354   272   383  230  449
# 3    2003   1105     556   179   433     64    157   134   180  102  181
# 4    2003   1106     888   322   700     76    207   168   270  166  364
#
#    Wast  Wstl  Wblk  Wto  Wpf
# 0   203    88    34  133  193
# 1   230    95    24  163  266
# 2   238   123    71  222  280
# 3   111    79    14  126  136
# 4   169   122    49  230  239

# %%
#Combined Stats with record
combined_stats = pd.merge(lteam_agg, wteam_agg,  how='outer', left_on=['Season','Lteam'], right_on = ['Season','Wteam'])
combined_stats = pd.merge(combined_stats, win_loss_record, how='inner', on=['Season','Lteam'])

# %%
combined_stats.head()
# Out:
#    Season   Lteam  Lscore   Lfgm   Lfga  Lfgm3  Lfga3   Lftm   Lfta    Lor  \
# 0    2003  1104.0   670.0  234.0  609.0   58.0  202.0  144.0  203.0  150.0
# 1    2003  1112.0   231.0   83.0  219.0   20.0   81.0   45.0   68.0   54.0
# 2    2003  1113.0   750.0  266.0  643.0   52.0  166.0  166.0  254.0  145.0
# 3    2003  1120.0   661.0  250.0  601.0   60.0  202.0  101.0  154.0  126.0
# 4    2003  1122.0   433.0  148.0  394.0   49.0  148.0   88.0  126.0   79.0
#
#       ...        Wast   Wstl   Wblk    Wto    Wpf    Team_Name  Total_Wins  \
# 0     ...       238.0  123.0   71.0  222.0  280.0      Alabama        17.0
# 1     ...       455.0  211.0  106.0  370.0  437.0      Arizona        25.0
# 2     ...       305.0  103.0   96.0  250.0  332.0   Arizona St        18.0
# 3     ...       293.0  170.0  110.0  294.0  311.0       Auburn        19.0
# 4     ...       279.0  139.0   92.0  295.0  361.0  Austin Peay        20.0
#
#    Total_Loses  Seed  Total_Games
# 0         11.0   Y10         28.0
# 1          3.0   Z01         28.0
# 2         11.0   Z10         29.0
# 3         11.0   W10         30.0
# 4          7.0   W13         27.0
#
# [5 rows x 36 columns]

# %%
#create new columns
# total pts and pts per game
combined_stats['Tpts']=combined_stats['Wscore']+combined_stats['Lscore']
combined_stats['Tpts_per_game']=combined_stats['Tpts']/combined_stats['Total_Games']

#Field goal attempted, made, and percentage
combined_stats['Tfga'] = combined_stats['Wfga']+combined_stats['Lfga']
combined_stats['Tfgm'] = combined_stats['Wfgm']+combined_stats['Lfgm']
combined_stats['Tfg_perct']=combined_stats['Tfgm']/combined_stats['Tfga']
combined_stats['Total_Tfga_game']=combined_stats['Tfga']/combined_stats['Total_Games']

#3pts attempted, made, and percentage
combined_stats['Tfga3'] = combined_stats['Wfga3']+combined_stats['Lfga3']
combined_stats['Tfgm3'] = combined_stats['Wfgm3']+combined_stats['Lfgm3']
combined_stats['Tfg3_perct']=combined_stats['Tfgm3']/combined_stats['Tfga3']
combined_stats['Total_3att_game']=combined_stats['Tfga3']/combined_stats['Total_Games']


#Free throws attempted, made, and percentage
combined_stats['Tfta'] = combined_stats['Wfta']+combined_stats['Lfta']
combined_stats['Tftm'] = combined_stats['Wftm']+combined_stats['Lftm']
combined_stats['Tft_perct']=combined_stats['Tftm'] /combined_stats['Tfta'] 
combined_stats['Tfta_att_game'] = combined_stats['Tfta'] /combined_stats['Total_Games']
#Total off rebounds and oof rebounds per game
combined_stats['Tor'] = combined_stats['Wor']+combined_stats['Lor']
combined_stats['Tor_per_game']=combined_stats['Tor']/combined_stats['Total_Games']

#Total def rebounds and def rebounds per game
combined_stats['Tdr'] = combined_stats['Wdr']+combined_stats['Ldr']
combined_stats['Tdr_perg_game']=combined_stats['Tdr']/combined_stats['Total_Games']

#Total rebounds and rebounds per game
combined_stats['Treb']=combined_stats['Tdr']+combined_stats['Tor']
combined_stats['Treb_per_game']=combined_stats['Treb']/combined_stats['Total_Games']

#total assists and assists per game
combined_stats['Tast'] = combined_stats['Wast']+combined_stats['Last']
combined_stats['Tast_per_game']=combined_stats['Tast']/combined_stats['Total_Games']

#total stls and stls per game
combined_stats['Tstl'] = combined_stats['Wstl']+combined_stats['Lstl']
combined_stats['Tstl_per_game'] = combined_stats['Tstl']/combined_stats['Total_Games']

#total fouls and fouls per game
combined_stats['Tpf'] = combined_stats['Wpf']+combined_stats['Lpf']
combined_stats['Tpf_per_game']=combined_stats['Tpf']/combined_stats['Total_Games']

#Total turnovers and turnover per game
combined_stats['Tto'] = combined_stats['Wto']+combined_stats['Lto']
combined_stats['Tto_per_game'] = combined_stats['Tto']/combined_stats['Total_Games']

#Total blocks and blocks per game
combined_stats['Tblk'] = combined_stats['Wblk']+combined_stats['Lblk']
combined_stats['Tblk_per_game'] = combined_stats['Tblk'] /combined_stats['Total_Games']

#Total Posessions
combined_stats['Tpos']=0.96*[(combined_stats['Tfga'])+(combined_stats['Tto'])+0.44*(combined_stats['Tfta'])-(combined_stats['Tor'])]

#Pos per game
combined_stats['Tpos_per_game']=combined_stats['Tpos']/combined_stats['Total_Games']

#points per posession
combined_stats['Pts_per_pos']=combined_stats['Tpts']/combined_stats['Tpos']

#Pts per 100 pos - ORtg
combined_stats['Tpos_per_100']=combined_stats['Pts_per_pos']*100

#source: https://www.nbastuffer.com/analytics101/possession/

combined_stats.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-1d5b001f59c7> in <module>()
#      55
#      56 #Total Posessions
# ---> 57 combined_stats['Tpos']=0.96*[(combined_stats['Tfga'].astype(float))+(combined_stats['Tto'].astype(float))+0.44*(combined_stats['Tfta'].astype(float))-(combined_stats['Tor'].astype(float))]
#      58
#      59 #Pos per game
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
#winning team first round
total_stats_win_first_round=pd.merge(combined_stats, first_round,  how='inner', left_on=['Season','Lteam'], right_on = ['Season','Wteam'])
total_stats_win_first_round['Win_1st_Round']=1
#losing team first round
total_stats_loss_first_round=pd.merge(combined_stats, first_round,  how='inner', left_on=['Season','Lteam'], right_on = ['Season','Lteam'])
total_stats_loss_first_round['Win_1st_Round']=0
#concat the two dataframes
frames = [total_stats_win_first_round, total_stats_loss_first_round]
stats_with_results=pd.concat(frames)

# %%
stats_with_results.columns
# Out:
# Index(['Daynum', 'Last', 'Lblk', 'Ldr', 'Lfga', 'Lfga3', 'Lfgm', 'Lfgm3',
#        'Lfta', 'Lftm', 'Lor', 'Lpf', 'Lscore_x', 'Lscore_y', 'Lstl', 'Lteam',
#        'Lteam_x', 'Lteam_y', 'Lto', 'Numot', 'Season', 'Seed', 'Tast',
#        'Tast_per_game', 'Tblk', 'Tblk_per_game', 'Tdr', 'Tdr_perg_game',
#        'Team_Name', 'Tfg3_perct', 'Tfg_perct', 'Tfga', 'Tfga3', 'Tfgm',
#        'Tfgm3', 'Tft_perct', 'Tfta', 'Tfta_att_game', 'Tftm', 'Tor',
#        'Tor_per_game', 'Total_3att_game', 'Total_Games', 'Total_Loses',
#        'Total_Tfga_game', 'Total_Wins', 'Tpf', 'Tpf_per_game', 'Tpts',
#        'Tpts_per_game', 'Treb', 'Treb_per_game', 'Tstl', 'Tstl_per_game',
#        'Tto', 'Tto_per_game', 'Wast', 'Wblk', 'Wdr', 'Wfga', 'Wfga3', 'Wfgm',
#        'Wfgm3', 'Wfta', 'Wftm', 'Win_1st_Round', 'Wloc', 'Wor', 'Wpf',
#        'Wscore_x', 'Wscore_y', 'Wstl', 'Wteam_x', 'Wteam_y', 'Wto'],
#       dtype='object')

# %% [markdown]
# # Visualizations

# %% [markdown]
# # Field Goal Percentage

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tfg_perct", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Field Goal Attempts per Game

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Total_Tfga_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # 3 PT FG %

# %%
#3P FG % Winning vs Losing teams
fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tfg3_perct", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # 3PT Attempts per Game

# %%
#3P Attempts Winning vs Losing teams
fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Total_3att_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # FT Percentage

# %%
#FT % Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tft_perct", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # FT Attempts per Game

# %%
#FTA Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tfta_att_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Steals per Game

# %%
#STLS Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tstl_per_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Def Rebounds Per Game

# %%
#DRB Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tdr_perg_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Off Rebounds per Game

# %%
#ORB Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tor_per_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Assists per Game

# %%
#Ast Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tast_per_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Blocks per Game

# %%
#Blocks Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tblk_per_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Fouls per Game

# %%
#Fouls Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tpf_per_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Turnovers per Game

# %%
#Turnovers Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tto_per_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Winning Percentage by Seed

# %%
wins_by_seed = stats_with_results.groupby(['Seed'])['Win_1st_Round'].mean().sort_values(ascending=True)
wins_by_seed
# Out:
# Seed
# Z16b    0.000000
# W15     0.000000
# W16b    0.000000
# W13     0.000000
# W12a    0.000000
# Z14a    0.000000
# X16     0.000000
# W16     0.000000
# X16a    0.000000
# Z16a    0.000000
# Y12a    0.000000
# Y16     0.000000
# Y16a    0.000000
# Y16b    0.000000
# Z16     0.000000
# X16b    0.000000
# W16a    0.000000
# Y15     0.076923
# X14     0.076923
# X15     0.076923
# Z15     0.076923
# W14     0.076923
# Y14     0.153846
# W11     0.166667
# Y13     0.230769
# Y10     0.230769
# W10     0.230769
# X13     0.230769
# Z14     0.250000
# Z13     0.250000
#           ...
# X08     0.615385
# Y05     0.615385
# Z09     0.615385
# Z05     0.615385
# X05     0.615385
# Y08     0.615385
# Z06     0.692308
# Z04     0.692308
# W08     0.692308
# Z03     0.769231
# X04     0.769231
# W06     0.769231
# W07     0.769231
# Y04     0.769231
# Y07     0.769231
# Y03     0.846154
# W03     0.923077
# Y02     0.923077
# X03     0.923077
# X02     0.923077
# Z02     0.923077
# Z13b    1.000000
# W01     1.000000
# X12b    1.000000
# X01     1.000000
# W11b    1.000000
# W04     1.000000
# W02     1.000000
# Z01     1.000000
# Y01     1.000000
# Name: Win_1st_Round, dtype: float64

# %% [markdown]
# # FG Percentage Trend

# %%
#FG Percentage Trend
sns.lmplot(x= 'Season', y='Tft_perct', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # FT Percentage Trend

# %%
sns.lmplot(x= 'Season', y='Tft_perct', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # 3PT Percentage Trend

# %%
sns.lmplot(x= 'Season', y='Tfg3_perct', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # Assists per Game Trend

# %%
sns.lmplot(x= 'Season', y='Tast_per_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # 3 Pt Attempts per Game Trend

# %%
sns.lmplot(x= 'Season', y='Total_3att_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # Def Rebounds per Game Trend

# %%
sns.lmplot(x= 'Season', y='Tdr_perg_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # Off Rebounds per Game Trend

# %%
sns.lmplot(x= 'Season', y='Tor_per_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # Stls per Game vs Pts

# %%
#Stls per game vs  Pts
sns.lmplot(x= 'Tstl_per_game', y='Tpts_per_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # FG Attempts per Game vs Pts

# %%
#FG Attempts vs  Pts
sns.lmplot(x= 'Total_Tfga_game', y='Tpts_per_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # Asts per Game vs Pts

# %%
#Ast per game vs  Pts
sns.lmplot(x= 'Tast_per_game', y='Tpts_per_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # 3 Pt Attempts per game vs  Pts

# %%
#3 Pt Attemts per game vs  Pts
sns.lmplot(x= 'Total_3att_game', y='Tpts_per_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # FG % vs  Pts

# %%
# FG % vs  Pts
sns.lmplot(x= 'Tfg_perct', y='Tpts_per_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %%
stats_with_results_totals=stats_with_results[[
       'Tast_per_game', 'Tblk_per_game',  'Tdr_perg_game',
        'Tfg3_perct', 'Tfg_perct', 
       'Tft_perct', 'Tfta_att_game', 
       'Tor_per_game', 'Total_3att_game', 
       'Total_Tfga_game',  'Tpf_per_game', 
       'Tpts_per_game', 'Treb_per_game', 'Tstl', 'Tstl_per_game',
        'Tto_per_game', 'Win_1st_Round']]

# %%
stats_with_results_totals=stats_with_results_totals.dropna()

# %%
corr_table=stats_with_results_totals.corr()

# %%
corr_table
# Out:
#                  Tast_per_game  Tblk_per_game  Tdr_perg_game  Tfg3_perct  \
# Tast_per_game         1.000000       0.093923       0.203428    0.335167
# Tblk_per_game         0.093923       1.000000       0.419643   -0.137871
# Tdr_perg_game         0.203428       0.419643       1.000000    0.011211
# Tfg3_perct            0.335167      -0.137871       0.011211    1.000000
# Tfg_perct             0.548108       0.033645       0.176673    0.550211
# Tft_perct             0.021348      -0.251533      -0.083538    0.285978
# Tfta_att_game        -0.038705       0.190281       0.335855   -0.102693
# Tor_per_game          0.168571       0.348346       0.226920   -0.301593
# Total_3att_game       0.152210      -0.176842      -0.129395    0.203989
# Total_Tfga_game       0.409106       0.275862       0.316834   -0.057595
# Tpf_per_game         -0.043448      -0.057352      -0.090521   -0.069710
# Tpts_per_game         0.581385       0.178966       0.382581    0.367893
# Treb_per_game         0.237383       0.490077       0.781211   -0.186190
# Tstl                  0.206169       0.187354      -0.180631   -0.128595
# Tstl_per_game         0.229661       0.145324      -0.222605   -0.122240
# Tto_per_game          0.112829       0.132883       0.156991   -0.103076
# Win_1st_Round         0.183435       0.195248       0.112869    0.076871
#
#                  Tfg_perct  Tft_perct  Tfta_att_game  Tor_per_game  \
# Tast_per_game     0.548108   0.021348      -0.038705      0.168571
# Tblk_per_game     0.033645  -0.251533       0.190281      0.348346
# Tdr_perg_game     0.176673  -0.083538       0.335855      0.226920
# Tfg3_perct        0.550211   0.285978      -0.102693     -0.301593
# Tfg_perct         1.000000   0.122628       0.030912     -0.231708
# Tft_perct         0.122628   1.000000      -0.086595     -0.344586
# Tfta_att_game     0.030912  -0.086595       1.000000      0.396360
# Tor_per_game     -0.231708  -0.344586       0.396360      1.000000
# Total_3att_game  -0.161918   0.112658      -0.217797     -0.074246
# Total_Tfga_game  -0.057827  -0.127957       0.226387      0.688975
# Tpf_per_game     -0.177191  -0.057707       0.349494      0.221554
# Tpts_per_game     0.491001   0.145638       0.474904      0.388373
# Treb_per_game    -0.036201  -0.273986       0.467585      0.785254
# Tstl             -0.038586  -0.195952       0.105302      0.305948
# Tstl_per_game    -0.020924  -0.185276       0.102866      0.302600
# Tto_per_game      0.077949  -0.197141       0.277428      0.305972
# Win_1st_Round     0.159718  -0.020930       0.030698      0.175306
#
#                  Total_3att_game  Total_Tfga_game  Tpf_per_game  \
# Tast_per_game           0.152210         0.409106     -0.043448
# Tblk_per_game          -0.176842         0.275862     -0.057352
# Tdr_perg_game          -0.129395         0.316834     -0.090521
# Tfg3_perct              0.203989        -0.057595     -0.069710
# Tfg_perct              -0.161918        -0.057827     -0.177191
# Tft_perct               0.112658        -0.127957     -0.057707
# Tfta_att_game          -0.217797         0.226387      0.349494
# Tor_per_game           -0.074246         0.688975      0.221554
# Total_3att_game         1.000000         0.239916      0.097089
# Total_Tfga_game         0.239916         1.000000      0.219625
# Tpf_per_game            0.097089         0.219625      1.000000
# Tpts_per_game           0.241648         0.731482      0.194465
# Treb_per_game          -0.129855         0.643054      0.084464
# Tstl                    0.117122         0.442254      0.226284
# Tstl_per_game           0.118203         0.432758      0.277075
# Tto_per_game           -0.166348         0.072504      0.375165
# Win_1st_Round          -0.011396         0.180377     -0.126585
#
#                  Tpts_per_game  Treb_per_game      Tstl  Tstl_per_game  \
# Tast_per_game         0.581385       0.237383  0.206169       0.229661
# Tblk_per_game         0.178966       0.490077  0.187354       0.145324
# Tdr_perg_game         0.382581       0.781211 -0.180631      -0.222605
# Tfg3_perct            0.367893      -0.186190 -0.128595      -0.122240
# Tfg_perct             0.491001      -0.036201 -0.038586      -0.020924
# Tft_perct             0.145638      -0.273986 -0.195952      -0.185276
# Tfta_att_game         0.474904       0.467585  0.105302       0.102866
# Tor_per_game          0.388373       0.785254  0.305948       0.302600
# Total_3att_game       0.241648      -0.129855  0.117122       0.118203
# Total_Tfga_game       0.731482       0.643054  0.442254       0.432758
# Tpf_per_game          0.194465       0.084464  0.226284       0.277075
# Tpts_per_game         1.000000       0.492171  0.291568       0.295535
# Treb_per_game         0.492171       1.000000  0.081271       0.052440
# Tstl                  0.291568       0.081271  1.000000       0.951532
# Tstl_per_game         0.295535       0.052440  0.951532       1.000000
# Tto_per_game          0.117704       0.295933  0.171132       0.268955
# Win_1st_Round         0.206628       0.184127  0.110961       0.073272
#
#                  Tto_per_game  Win_1st_Round
# Tast_per_game        0.112829       0.183435
# Tblk_per_game        0.132883       0.195248
# Tdr_perg_game        0.156991       0.112869
# Tfg3_perct          -0.103076       0.076871
# Tfg_perct            0.077949       0.159718
# Tft_perct           -0.197141      -0.020930
# Tfta_att_game        0.277428       0.030698
# Tor_per_game         0.305972       0.175306
# Total_3att_game     -0.166348      -0.011396
# Total_Tfga_game      0.072504       0.180377
# Tpf_per_game         0.375165      -0.126585
# Tpts_per_game        0.117704       0.206628
# Treb_per_game        0.295933       0.184127
# Tstl                 0.171132       0.110961
# Tstl_per_game        0.268955       0.073272
# Tto_per_game         1.000000      -0.181003
# Win_1st_Round       -0.181003       1.000000

# %%
fig, ax = plt.subplots(figsize=(20,8))
sns.heatmap(corr_table, annot=False, ax=ax)
