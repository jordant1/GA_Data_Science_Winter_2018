# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sns
# %matplotlib inline

# %%
reg_season_compact = pd.read_csv('RegularSeasonCompactResults.csv')
reg_season_detail = pd.read_csv('RegularSeasonDetailedResults.csv')
tourn_compact = pd.read_csv('TourneyCompactResults.csv')
tourn_detail = pd.read_csv('TourneyDetailedResults.csv')
tourn_seeds = pd.read_csv('TourneySeeds.csv')
seasons = pd.read_csv('Seasons.csv')
teams = pd.read_csv('Teams.csv')

# %%
#dataframe of first round results
first_round = tourn_compact[(tourn_compact['Daynum']==137) | (tourn_compact['Daynum']==136)]

# %%
reg_season_compact.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0

# %% [markdown]
# # Create Wins and Loss Tables

# %%
#calculate total loses per season
loses_season=reg_season_detail[['Season','Lteam']]
loses_season=loses_season.groupby(['Season','Lteam']).size()
loses_season = loses_season.to_frame(name = 'size').reset_index()
loses_season.columns=['Season','Lteam','Total_Loses']
loses_season
#Calculate total wins per season
wins_season=reg_season_detail[['Season','Wteam']]
wins_season=wins_season.groupby(['Season','Wteam']).size()
wins_season = wins_season.to_frame(name = 'size').reset_index()
wins_season.columns=['Season','Wteam','Total_Wins']
wins_season
#combine tables for record per season
win_loss_record = pd.merge(loses_season, wins_season,  how='outer', left_on=['Season','Lteam'], right_on = ['Season','Wteam'])
win_loss_record = pd.merge(win_loss_record, teams, how='inner', left_on='Lteam', right_on='Team_Id')
win_loss_record= pd.merge(win_loss_record,tourn_seeds,how='inner', left_on=['Season','Lteam'], right_on=['Season','Team'])
win_loss_record=win_loss_record[['Season','Lteam','Team_Name','Total_Wins', 'Total_Loses','Seed']]
win_loss_record['Total_Games']=win_loss_record['Total_Wins']+win_loss_record['Total_Loses']

# %% [markdown]
# # Winning Team Aggregate Stats

# %%
#Winning Team Aggregate Stats
wteam_agg=reg_season_detail.groupby(['Season','Wteam']).agg({'Wscore':'sum', 'Wfgm':'sum', 'Wfga':'sum'
                                                            ,'Wfgm3':'sum','Wfga3':'sum','Wftm':'sum',
                                                            'Wftm':'sum','Wfta':'sum','Wor':'sum','Wdr':'sum',
                                                             'Wast':'sum','Wstl':'sum',
                                                            'Wblk':'sum','Wto':'sum',
                                                            'Wpf':'sum'}).reset_index()

# %% [markdown]
# # Losing Team Aggregate Stats

# %%
#Losing Team Aggregate Stats
lteam_agg=reg_season_detail.groupby(['Season','Lteam']).agg({'Lscore':'sum', 'Lfgm':'sum', 'Lfga':'sum'
                                                            ,'Lfgm3':'sum','Lfga3':'sum','Lftm':'sum',
                                                            'Lftm':'sum','Lfta':'sum','Lor':'sum','Ldr':'sum',
                                                             'Last':'sum','Lstl':'sum',
                                                            'Lblk':'sum','Lto':'sum',
                                                            'Lpf':'sum'}).reset_index()

# %%
wteam_agg.head()
# Out:
#    Season  Wteam  Wscore  Wfgm  Wfga  Wfgm3  Wfga3  Wftm  Wfta  Wor  Wdr  \
# 0    2003   1102     825   271   480    120    259   163   249   46  232
# 1    2003   1103    1141   390   720     71    187   290   402  122  279
# 2    2003   1104    1270   439   992    120    354   272   383  230  449
# 3    2003   1105     556   179   433     64    157   134   180  102  181
# 4    2003   1106     888   322   700     76    207   168   270  166  364
#
#    Wast  Wstl  Wblk  Wto  Wpf
# 0   203    88    34  133  193
# 1   230    95    24  163  266
# 2   238   123    71  222  280
# 3   111    79    14  126  136
# 4   169   122    49  230  239

# %%
#Combined Stats with record
combined_stats = pd.merge(lteam_agg, wteam_agg,  how='outer', left_on=['Season','Lteam'], right_on = ['Season','Wteam'])
combined_stats = pd.merge(combined_stats, win_loss_record, how='inner', on=['Season','Lteam'])

# %%
combined_stats.head()
# Out:
#    Season   Lteam  Lscore   Lfgm   Lfga  Lfgm3  Lfga3   Lftm   Lfta    Lor  \
# 0    2003  1104.0   670.0  234.0  609.0   58.0  202.0  144.0  203.0  150.0
# 1    2003  1112.0   231.0   83.0  219.0   20.0   81.0   45.0   68.0   54.0
# 2    2003  1113.0   750.0  266.0  643.0   52.0  166.0  166.0  254.0  145.0
# 3    2003  1120.0   661.0  250.0  601.0   60.0  202.0  101.0  154.0  126.0
# 4    2003  1122.0   433.0  148.0  394.0   49.0  148.0   88.0  126.0   79.0
#
#       ...        Wast   Wstl   Wblk    Wto    Wpf    Team_Name  Total_Wins  \
# 0     ...       238.0  123.0   71.0  222.0  280.0      Alabama        17.0
# 1     ...       455.0  211.0  106.0  370.0  437.0      Arizona        25.0
# 2     ...       305.0  103.0   96.0  250.0  332.0   Arizona St        18.0
# 3     ...       293.0  170.0  110.0  294.0  311.0       Auburn        19.0
# 4     ...       279.0  139.0   92.0  295.0  361.0  Austin Peay        20.0
#
#    Total_Loses  Seed  Total_Games
# 0         11.0   Y10         28.0
# 1          3.0   Z01         28.0
# 2         11.0   Z10         29.0
# 3         11.0   W10         30.0
# 4          7.0   W13         27.0
#
# [5 rows x 36 columns]

# %%
#create new columns
# total pts and pts per game
combined_stats['Tpts']=combined_stats['Wscore']+combined_stats['Lscore']
combined_stats['Tpts_per_game']=combined_stats['Tpts']/combined_stats['Total_Games']

#Field goal attempted, made, and percentage
combined_stats['Tfga'] = combined_stats['Wfga']+combined_stats['Lfga']
combined_stats['Tfgm'] = combined_stats['Wfgm']+combined_stats['Lfgm']
combined_stats['Tfg_perct']=combined_stats['Tfgm']/combined_stats['Tfga']
combined_stats['Total_Tfga_game']=combined_stats['Tfga']/combined_stats['Total_Games']


#3pts attempted, made, and percentage
combined_stats['Tfga3'] = combined_stats['Wfga3']+combined_stats['Lfga3']
combined_stats['Tfgm3'] = combined_stats['Wfgm3']+combined_stats['Lfgm3']
combined_stats['Tfg3_perct']=combined_stats['Tfgm3']/combined_stats['Tfga3']
combined_stats['Total_3att_game']=combined_stats['Tfga3']/combined_stats['Total_Games']

#Free throws attempted, made, and percentage
combined_stats['Tfta'] = combined_stats['Wfta']+combined_stats['Lfta']
combined_stats['Tftm'] = combined_stats['Wftm']+combined_stats['Lftm']
combined_stats['Tft_perct']=combined_stats['Tftm'] /combined_stats['Tfta'] 
combined_stats['Tfta_att_game'] = combined_stats['Tfta'] /combined_stats['Total_Games']
#Total off rebounds and oof rebounds per game
combined_stats['Tor'] = combined_stats['Wor']+combined_stats['Lor']
combined_stats['Tor_per_game']=combined_stats['Tor']/combined_stats['Total_Games']

#Total def rebounds and def rebounds per game
combined_stats['Tdr'] = combined_stats['Wdr']+combined_stats['Ldr']
combined_stats['Tdr_perg_game']=combined_stats['Tdr']/combined_stats['Total_Games']

#Total rebounds and rebounds per game
combined_stats['Treb']=combined_stats['Tdr']+combined_stats['Tor']
combined_stats['Treb_per_game']=combined_stats['Treb']/combined_stats['Total_Games']

#total assists and assists per game
combined_stats['Tast'] = combined_stats['Wast']+combined_stats['Last']
combined_stats['Tast_per_game']=combined_stats['Tast']/combined_stats['Total_Games']

#total stls and stls per game
combined_stats['Tstl'] = combined_stats['Wstl']+combined_stats['Lstl']
combined_stats['Tstl_per_game'] = combined_stats['Tstl']/combined_stats['Total_Games']

#total fouls and fouls per game
combined_stats['Tpf'] = combined_stats['Wpf']+combined_stats['Lpf']
combined_stats['Tpf_per_game']=combined_stats['Tpf']/combined_stats['Total_Games']

#Total turnovers and turnover per game
combined_stats['Tto'] = combined_stats['Wto']+combined_stats['Lto']
combined_stats['Tto_per_game'] = combined_stats['Tto']/combined_stats['Total_Games']

#Total blocks and blocks per game
combined_stats['Tblk'] = combined_stats['Wblk']+combined_stats['Lblk']
combined_stats['Tblk_per_game'] = combined_stats['Tblk'] /combined_stats['Total_Games']

combined_stats.head()
# Out:
#    Season   Lteam  Lscore   Lfgm   Lfga  Lfgm3  Lfga3   Lftm   Lfta    Lor  \
# 0    2003  1104.0   670.0  234.0  609.0   58.0  202.0  144.0  203.0  150.0
# 1    2003  1112.0   231.0   83.0  219.0   20.0   81.0   45.0   68.0   54.0
# 2    2003  1113.0   750.0  266.0  643.0   52.0  166.0  166.0  254.0  145.0
# 3    2003  1120.0   661.0  250.0  601.0   60.0  202.0  101.0  154.0  126.0
# 4    2003  1122.0   433.0  148.0  394.0   49.0  148.0   88.0  126.0   79.0
#
#        ...         Tast  Tast_per_game   Tstl  Tstl_per_game    Tpf  \
# 0      ...        339.0      12.107143  185.0       6.607143  505.0
# 1      ...        494.0      17.642857  237.0       8.464286  497.0
# 2      ...        451.0      15.551724  151.0       5.206897  563.0
# 3      ...        402.0      13.400000  241.0       8.033333  491.0
# 4      ...        362.0      13.407407  190.0       7.037037  504.0
#
#    Tpf_per_game    Tto  Tto_per_game   Tblk  Tblk_per_game
# 0     18.035714  372.0     13.285714  106.0       3.785714
# 1     17.750000  414.0     14.785714  118.0       4.214286
# 2     19.413793  406.0     14.000000  123.0       4.241379
# 3     16.366667  477.0     15.900000  149.0       4.966667
# 4     18.666667  411.0     15.222222  126.0       4.666667
#
# [5 rows x 66 columns]

# %%
#winning team first round
total_stats_win_first_round=pd.merge(combined_stats, first_round,  how='inner', left_on=['Season','Lteam'], right_on = ['Season','Wteam'])
total_stats_win_first_round['Win_1st_Round']=1
#losing team first round
total_stats_loss_first_round=pd.merge(combined_stats, first_round,  how='inner', left_on=['Season','Lteam'], right_on = ['Season','Lteam'])
total_stats_loss_first_round['Win_1st_Round']=0
#concat the two dataframes
frames = [total_stats_win_first_round, total_stats_loss_first_round]
stats_with_results=pd.concat(frames)

# %%
stats_with_results.columns
# Out:
# Index(['Daynum', 'Last', 'Lblk', 'Ldr', 'Lfga', 'Lfga3', 'Lfgm', 'Lfgm3',
#        'Lfta', 'Lftm', 'Lor', 'Lpf', 'Lscore_x', 'Lscore_y', 'Lstl', 'Lteam',
#        'Lteam_x', 'Lteam_y', 'Lto', 'Numot', 'Season', 'Seed', 'Tast',
#        'Tast_per_game', 'Tblk', 'Tblk_per_game', 'Tdr', 'Tdr_perg_game',
#        'Team_Name', 'Tfg3_perct', 'Tfg_perct', 'Tfga', 'Tfga3', 'Tfgm',
#        'Tfgm3', 'Tft_perct', 'Tfta', 'Tfta_att_game', 'Tftm', 'Tor',
#        'Tor_per_game', 'Total_3att_game', 'Total_Games', 'Total_Loses',
#        'Total_Tfga_game', 'Total_Wins', 'Tpf', 'Tpf_per_game', 'Tpts',
#        'Tpts_per_game', 'Treb', 'Treb_per_game', 'Tstl', 'Tstl_per_game',
#        'Tto', 'Tto_per_game', 'Wast', 'Wblk', 'Wdr', 'Wfga', 'Wfga3', 'Wfgm',
#        'Wfgm3', 'Wfta', 'Wftm', 'Win_1st_Round', 'Wloc', 'Wor', 'Wpf',
#        'Wscore_x', 'Wscore_y', 'Wstl', 'Wteam_x', 'Wteam_y', 'Wto'],
#       dtype='object')

# %% [markdown]
# # Visualizations

# %% [markdown]
# # Field Goal Percentage

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tfg_perct", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Field Goal Attempts per Game

# %%
fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Total_Tfga_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # 3 PT FG %

# %%
#3P FG % Winning vs Losing teams
fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tfg3_perct", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # 3PT Attempts per Game

# %%
#3P Attempts Winning vs Losing teams
fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Total_3att_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # FT Percentage

# %%
#FT % Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tft_perct", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # FT Attempts per Game

# %%
#FTA Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tfta_att_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Steals per Game

# %%
#STLS Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tstl_per_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Def Rebounds Per Game

# %%
#DRB Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tdr_perg_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Off Rebounds per Game

# %%
#ORB Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tor_per_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Assists per Game

# %%
#Ast Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tast_per_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Blocks per Game

# %%
#Blocks Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tblk_per_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Fouls per Game

# %%
#Fouls Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tpf_per_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Turnovers per Game

# %%
#Turnovers Winning vs Losing teams

fig, ax = plt.subplots(figsize=(20,8))
ax = sns.violinplot(x="Season", y="Tto_per_game", hue="Win_1st_Round",
 data=stats_with_results,ax=ax)

# %% [markdown]
# # Winning Percentage by Seed

# %%
wins_by_seed = stats_with_results.groupby(['Seed'])['Win_1st_Round'].mean().sort_values(ascending=True)
wins_by_seed
# Out:
# Seed
# Z16b    0.000000
# W15     0.000000
# W16b    0.000000
# W13     0.000000
# W12a    0.000000
# Z14a    0.000000
# X16     0.000000
# W16     0.000000
# X16a    0.000000
# Z16a    0.000000
# Y12a    0.000000
# Y16     0.000000
# Y16a    0.000000
# Y16b    0.000000
# Z16     0.000000
# X16b    0.000000
# W16a    0.000000
# Y15     0.076923
# X14     0.076923
# X15     0.076923
# Z15     0.076923
# W14     0.076923
# Y14     0.153846
# W11     0.166667
# Y13     0.230769
# Y10     0.230769
# W10     0.230769
# X13     0.230769
# Z14     0.250000
# Z13     0.250000
#           ...
# X08     0.615385
# Y05     0.615385
# Z09     0.615385
# Z05     0.615385
# X05     0.615385
# Y08     0.615385
# Z06     0.692308
# Z04     0.692308
# W08     0.692308
# Z03     0.769231
# X04     0.769231
# W06     0.769231
# W07     0.769231
# Y04     0.769231
# Y07     0.769231
# Y03     0.846154
# W03     0.923077
# Y02     0.923077
# X03     0.923077
# X02     0.923077
# Z02     0.923077
# Z13b    1.000000
# W01     1.000000
# X12b    1.000000
# X01     1.000000
# W11b    1.000000
# W04     1.000000
# W02     1.000000
# Z01     1.000000
# Y01     1.000000
# Name: Win_1st_Round, dtype: float64

# %% [markdown]
# # FG Percentage Trend

# %%
#FG Percentage Trend
sns.lmplot(x= 'Season', y='Tft_perct', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # FT Percentage Trend

# %%
sns.lmplot(x= 'Season', y='Tft_perct', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # 3PT Percentage Trend

# %%
sns.lmplot(x= 'Season', y='Tfg3_perct', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # Assists per Game Trend

# %%
sns.lmplot(x= 'Season', y='Tast_per_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # 3 Pt Attempts per Game Trend

# %%
sns.lmplot(x= 'Season', y='Total_3att_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # Def Rebounds per Game Trend

# %%
sns.lmplot(x= 'Season', y='Tdr_perg_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %% [markdown]
# # Off Rebounds per Game Trend

# %%
sns.lmplot(x= 'Season', y='Tor_per_game', data=stats_with_results, hue='Win_1st_Round')
plt.show()

# %%
stats_with_results_totals=stats_with_results[['Tast',
       'Tast_per_game', 'Tblk', 'Tblk_per_game', 'Tdr', 'Tdr_perg_game',
       'Team_Name', 'Tfg3_perct', 'Tfg_perct', 'Tfga', 'Tfga3', 'Tfgm',
       'Tfgm3', 'Tft_perct', 'Tfta', 'Tfta_att_game', 'Tftm', 'Tor',
       'Tor_per_game', 'Total_3att_game', 'Total_Games', 'Total_Loses',
       'Total_Tfga_game', 'Total_Wins', 'Tpf', 'Tpf_per_game', 'Tpts',
       'Tpts_per_game', 'Treb', 'Treb_per_game', 'Tstl', 'Tstl_per_game',
       'Tto', 'Tto_per_game', 'Win_1st_Round']]

# %%
stats_with_results_totals=stats_with_results_totals.dropna()

# %%
stats_with_results_totals.corr()
# Out:
#                      Tast  Tast_per_game      Tblk  Tblk_per_game       Tdr  \
# Tast             1.000000       0.897616  0.215912       0.154836  0.411144
# Tast_per_game    0.897616       1.000000  0.080667       0.093923  0.117937
# Tblk             0.215912       0.080667  1.000000       0.983590  0.503448
# Tblk_per_game    0.154836       0.093923  0.983590       1.000000  0.401372
# Tdr              0.411144       0.117937  0.503448       0.401372  1.000000
# Tdr_perg_game    0.241398       0.203428  0.421070       0.419643  0.802409
# Tfg3_perct       0.298654       0.335167 -0.137456      -0.137871 -0.008208
# Tfg_perct        0.485530       0.548108  0.024125       0.033645  0.101327
# Tfga             0.542046       0.251637  0.406888       0.297377  0.643115
# Tfga3            0.258172       0.121576 -0.044777      -0.111097  0.144025
# Tfgm             0.731387       0.496695  0.383446       0.288537  0.639434
# Tfgm3            0.334024       0.228751 -0.089614      -0.146733  0.124073
# Tft_perct       -0.007904       0.021348 -0.252770      -0.251533 -0.098395
# Tfta             0.133415      -0.060027  0.298829       0.234583  0.516836
# Tfta_att_game   -0.031098      -0.038705  0.182491       0.190281  0.254045
# Tftm             0.126365      -0.051827  0.203071       0.141269  0.468723
# Tor              0.290794       0.132358  0.427039       0.376196  0.409479
# Tor_per_game     0.166637       0.168571  0.336865       0.348346  0.180818
# Total_3att_game  0.136698       0.152210 -0.165958      -0.176842 -0.095146
# Total_Games      0.387379      -0.054793  0.322436       0.155411  0.686816
# Total_Loses     -0.280373      -0.345817 -0.093694      -0.114045 -0.077220
# Total_Tfga_game  0.402761       0.409106  0.272721       0.275862  0.267039
# Total_Wins       0.463133       0.276255  0.261653       0.187188  0.448862
# Tpf              0.107091      -0.072472  0.100733       0.032193  0.222541
# Tpf_per_game    -0.111581      -0.043448 -0.082067      -0.057352 -0.164067
# Tpts             0.658406       0.402242  0.338006       0.234921  0.660344
# Tpts_per_game    0.539046       0.581385  0.171447       0.178966  0.285215
# Treb             0.424883       0.147757  0.557793       0.463596  0.875951
# Treb_per_game    0.260283       0.237383  0.483625       0.490077  0.626040
# Tstl             0.286376       0.206169  0.217636       0.187354 -0.000157
# Tstl_per_game    0.173911       0.229661  0.123860       0.145324 -0.212755
# Tto              0.150027       0.087192  0.234444       0.213349  0.251578
# Tto_per_game    -0.030894       0.112829  0.076064       0.132883 -0.069974
# Win_1st_Round    0.226622       0.183435  0.206774       0.195248  0.162170
#
#                  Tdr_perg_game  Tfg3_perct  Tfg_perct      Tfga     Tfga3  \
# Tast                  0.241398    0.298654   0.485530  0.542046  0.258172
# Tast_per_game         0.203428    0.335167   0.548108  0.251637  0.121576
# Tblk                  0.421070   -0.137456   0.024125  0.406888 -0.044777
# Tblk_per_game         0.419643   -0.137871   0.033645  0.297377 -0.111097
# Tdr                   0.802409   -0.008208   0.101327  0.643115  0.144025
# Tdr_perg_game         1.000000    0.011211   0.176673  0.299662 -0.080733
# Tfg3_perct            0.011211    1.000000   0.550211 -0.061984  0.178879
# Tfg_perct             0.176673    0.550211   1.000000 -0.076376 -0.171782
# Tfga                  0.299662   -0.061984  -0.076376  1.000000  0.402147
# Tfga3                -0.080733    0.178879  -0.171782  0.402147  1.000000
# Tfgm                  0.364975    0.211919   0.415084  0.874392  0.280515
# Tfgm3                -0.062370    0.511559   0.053992  0.327331  0.934470
# Tft_perct            -0.083538    0.285978   0.122628 -0.131110  0.085095
# Tfta                  0.349362   -0.105438   0.005730  0.450981 -0.031904
# Tfta_att_game         0.335855   -0.102693   0.030912  0.169441 -0.197022
# Tftm                  0.311299   -0.003953   0.047192  0.393441 -0.002347
# Tor                   0.244626   -0.292123  -0.234625  0.720877  0.067692
# Tor_per_game          0.226920   -0.301593  -0.231708  0.506214 -0.058709
# Total_3att_game      -0.129395    0.203989  -0.161918  0.169524  0.938706
# Total_Games           0.119627   -0.033033  -0.056595  0.710134  0.339395
# Total_Loses          -0.177208   -0.276201  -0.443176 -0.003758 -0.016647
# Total_Tfga_game       0.316834   -0.057595  -0.057827  0.747087  0.248404
# Total_Wins            0.223370    0.226586   0.361577  0.396644  0.202735
# Tpf                  -0.021246   -0.084836  -0.198673  0.436348  0.222510
# Tpf_per_game         -0.090521   -0.069710  -0.177191  0.050481  0.038389
# Tpts                  0.365053    0.259177   0.338880  0.852660  0.394733
# Tpts_per_game         0.382581    0.367893   0.491001  0.521341  0.230988
# Treb                  0.658484   -0.159876  -0.057243  0.805264  0.130768
# Treb_per_game         0.781211   -0.186190  -0.036201  0.514990 -0.088958
# Tstl                 -0.180631   -0.128595  -0.038586  0.462351  0.188161
# Tstl_per_game        -0.222605   -0.122240  -0.020924  0.252227  0.085097
# Tto                   0.213663   -0.123138   0.050182  0.177865 -0.105533
# Tto_per_game          0.156991   -0.103076   0.077949 -0.152346 -0.258738
# Win_1st_Round         0.112869    0.076871   0.159718  0.213532  0.035673
#
#                      ...        Tpf_per_game      Tpts  Tpts_per_game  \
# Tast                 ...           -0.111581  0.658406       0.539046
# Tast_per_game        ...           -0.043448  0.402242       0.581385
# Tblk                 ...           -0.082067  0.338006       0.171447
# Tblk_per_game        ...           -0.057352  0.234921       0.178966
# Tdr                  ...           -0.164067  0.660344       0.285215
# Tdr_perg_game        ...           -0.090521  0.365053       0.382581
# Tfg3_perct           ...           -0.069710  0.259177       0.367893
# Tfg_perct            ...           -0.177191  0.338880       0.491001
# Tfga                 ...            0.050481  0.852660       0.521341
# Tfga3                ...            0.038389  0.394733       0.230988
# Tfgm                 ...           -0.041274  0.943065       0.715438
# Tfgm3                ...            0.003845  0.439752       0.338312
# Tft_perct            ...           -0.057707  0.070104       0.145638
# Tfta                 ...            0.248471  0.608277       0.430199
# Tfta_att_game        ...            0.349494  0.368417       0.474904
# Tftm                 ...            0.221600  0.616771       0.470030
# Tor                  ...            0.148702  0.517753       0.354999
# Tor_per_game         ...            0.221554  0.309434       0.388373
# Total_3att_game      ...            0.097089  0.181746       0.241648
# Total_Games          ...           -0.158865  0.654440       0.008394
# Total_Loses          ...            0.197094 -0.209523      -0.353937
# Total_Tfga_game      ...            0.219625  0.590402       0.731482
# Total_Wins           ...           -0.262733  0.548230       0.318451
# Tpf                  ...            0.839027  0.397160       0.182506
# Tpf_per_game         ...            1.000000  0.042541       0.194465
# Tpts                 ...            0.042541  1.000000       0.760258
# Tpts_per_game        ...            0.194465  0.760258       1.000000
# Treb                 ...           -0.029563  0.709221       0.375791
# Treb_per_game        ...            0.084464  0.430429       0.492171
# Tstl                 ...            0.226284  0.364550       0.291568
# Tstl_per_game        ...            0.277075  0.169435       0.295535
# Tto                  ...            0.312823  0.191133       0.118714
# Tto_per_game         ...            0.375165 -0.112166       0.117704
# Win_1st_Round        ...           -0.126585  0.240311       0.206628
#
#                      Treb  Treb_per_game      Tstl  Tstl_per_game       Tto  \
# Tast             0.424883       0.260283  0.286376       0.173911  0.150027
# Tast_per_game    0.147757       0.237383  0.206169       0.229661  0.087192
# Tblk             0.557793       0.483625  0.217636       0.123860  0.234444
# Tblk_per_game    0.463596       0.490077  0.187354       0.145324  0.213349
# Tdr              0.875951       0.626040 -0.000157      -0.212755  0.251578
# Tdr_perg_game    0.658484       0.781211 -0.180631      -0.222605  0.213663
# Tfg3_perct      -0.159876      -0.186190 -0.128595      -0.122240 -0.123138
# Tfg_perct       -0.057243      -0.036201 -0.038586      -0.020924  0.050182
# Tfga             0.805264       0.514990  0.462351       0.252227  0.177865
# Tfga3            0.130768      -0.088958  0.188161       0.085097 -0.105533
# Tfgm             0.708480       0.455860  0.401522       0.218996  0.187166
# Tfgm3            0.056166      -0.142739  0.115062       0.028560 -0.140320
# Tft_perct       -0.245858      -0.273986 -0.195952      -0.185276 -0.231672
# Tfta             0.601399       0.456837  0.188541       0.057548  0.323208
# Tfta_att_game    0.361806       0.467585  0.105302       0.102866  0.287924
# Tftm             0.499865       0.350048  0.119718      -0.003598  0.236503
# Tor              0.798787       0.752258  0.364056       0.250220  0.361062
# Tor_per_game     0.611495       0.785254  0.305948       0.302600  0.329254
# Total_3att_game -0.099314      -0.129855  0.117122       0.118203 -0.171631
# Total_Games      0.660078       0.097858  0.220954      -0.083694  0.164030
# Total_Loses     -0.065204      -0.154576 -0.143814      -0.174828  0.219608
# Total_Tfga_game  0.521462       0.643054  0.442254       0.432758  0.100958
# Total_Wins       0.423398       0.191247  0.249883       0.108649 -0.103856
# Tpf              0.333741       0.130247  0.333608       0.212935  0.379929
# Tpf_per_game    -0.029563       0.084464  0.226284       0.277075  0.312823
# Tpts             0.709221       0.430429  0.364550       0.169435  0.191133
# Tpts_per_game    0.375791       0.492171  0.291568       0.295535  0.118714
# Treb             1.000000       0.810598  0.192396      -0.007991  0.356815
# Treb_per_game    0.810598       1.000000  0.081271       0.052440  0.346886
# Tstl             0.192396       0.081271  1.000000       0.951532  0.281964
# Tstl_per_game   -0.007991       0.052440  0.951532       1.000000  0.237049
# Tto              0.356815       0.346886  0.281964       0.237049  1.000000
# Tto_per_game     0.044054       0.295933  0.171132       0.268955  0.888761
# Win_1st_Round    0.216387       0.184127  0.110961       0.073272 -0.125540
#
#                  Tto_per_game  Win_1st_Round
# Tast                -0.030894       0.226622
# Tast_per_game        0.112829       0.183435
# Tblk                 0.076064       0.206774
# Tblk_per_game        0.132883       0.195248
# Tdr                 -0.069974       0.162170
# Tdr_perg_game        0.156991       0.112869
# Tfg3_perct          -0.103076       0.076871
# Tfg_perct            0.077949       0.159718
# Tfga                -0.152346       0.213532
# Tfga3               -0.258738       0.035673
# Tfgm                -0.100124       0.272418
# Tfgm3               -0.265176       0.063041
# Tft_perct           -0.197141      -0.020930
# Tfta                 0.116036       0.080063
# Tfta_att_game        0.277428       0.030698
# Tftm                 0.047217       0.068871
# Tor                  0.170582       0.206986
# Tor_per_game         0.305972       0.175306
# Total_3att_game     -0.166348      -0.011396
# Total_Games         -0.302558       0.131328
# Total_Loses          0.167762      -0.330838
# Total_Tfga_game      0.072504       0.180377
# Total_Wins          -0.316312       0.366059
# Tpf                  0.180473      -0.046809
# Tpf_per_game         0.375165      -0.126585
# Tpts                -0.112166       0.240311
# Tpts_per_game        0.117704       0.206628
# Treb                 0.044054       0.216387
# Treb_per_game        0.295933       0.184127
# Tstl                 0.171132       0.110961
# Tstl_per_game        0.268955       0.073272
# Tto                  0.888761      -0.125540
# Tto_per_game         1.000000      -0.181003
# Win_1st_Round       -0.181003       1.000000
#
# [34 rows x 34 columns]
